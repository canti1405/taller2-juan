# %% [markdown]
# # Analítica computacional para la toma de decisiones
#
# Departamento de Ingeniería Industrial
#
# Universidad de los Andes

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#cargo el archivo
d = pd.read_csv('/Users/juan/Downloads/BikePrices.csv')

#cuantas filas y columnas tiene
d.count

copia=d
# Out:
# <bound method DataFrame.count of       Brand                      Model  Selling_Price  Year Seller_Type  \
# 0       TVS                 TVS XL 100          30000  2017  Individual
# 1     Bajaj              Bajaj  ct 100          18000  2017  Individual
# 2        Yo                   Yo Style          20000  2011  Individual
# 3     Bajaj         Bajaj Discover 100          25000  2010  Individual
# 4     Bajaj         Bajaj Discover 100          24999  2012  Individual
# ...     ...                        ...            ...   ...         ...
# 1056  Royal  Royal Enfield Electra 5 S          90000  2012  Individual
# 1057   Hero            Hero Honda Hunk          20000  2010  Individual
# 1058  Bajaj     Bajaj Pulsar 220 DTS-i          60000  2014  Individual
# 1059   Hero     Hero Honda CBZ extreme          40000  2009  Individual
# 1060   Hero     Hero Honda CBZ extreme          35000  2012  Individual
#
#           Owner  KM_Driven  Ex_Showroom_Price
# ...

# %%
#verfifico que todo se haya cargado correctamente
d.head()

de=1

# %%
#medidas estadisticas
d.describe()
# Out:
#        Selling_Price         Year      KM_Driven  Ex_Showroom_Price
# count    1061.000000  1061.000000    1061.000000       6.260000e+02
# mean    59638.151744  2013.867107   34359.833176       8.795871e+04
# std     56304.291973     4.301191   51623.152702       7.749659e+04
# min      5000.000000  1988.000000     350.000000       3.049000e+04
# 25%     28000.000000  2011.000000   13500.000000       5.485200e+04
# 50%     45000.000000  2015.000000   25000.000000       7.275250e+04
# 75%     70000.000000  2017.000000   43000.000000       8.703150e+04
# max    760000.000000  2020.000000  880000.000000       1.278000e+06

# %%
#grafica 1
plt.figure(figsize=(8, 5))
plt.hist(d['Selling_Price'])
plt.title('Distribución de Precios de Bicicletas')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Gráfico 3: Scatter plot entre Precio y Peso
plt.scatter(d['KM_Driven'], d['Selling_Price'])
plt.title('Relación entre Peso y Kms(uso) de Bicicletas')
plt.xlabel('kms')
plt.ylabel('Precio')
plt.show()

# %%
# Gráfico 3: Scatter plot entre Precio actual y anterior
plt.scatter(d['Ex_Showroom_Price'], d['Selling_Price'])
plt.title('Relación entre Precio actual y anterior de Bicicletas')
plt.xlabel('Precio anterior')
plt.ylabel('Precio')
plt.show()
